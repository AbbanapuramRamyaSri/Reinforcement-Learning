# %% [markdown]
# <a href="https://colab.research.google.com/github/AbbanapuramRamyaSri/Reinforcement-Learning/blob/main/Lab_Ass_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

machines = ['A', 'B', 'C']
M = 3
N_play = 10

N = [0, 0, 0]
R = [0.0, 0.0, 0.0]
Q = [0.0, 0.0, 0.0]
UCB = [0.0, 0.0, 0.0]

for play in range(1, N_play + 1):
    for i in range(M):
        if N[i] == 0:
            UCB[i] = float('inf')
        else:
            UCB[i] = Q[i] + math.sqrt((2 * math.log(play)) / N[i])

    selected = UCB.index(max(UCB))
    machine = machines[selected]

    print("\nPlay", play)
    print("UCB =", ["inf" if x == float('inf') else round(x, 2) for x in UCB])
    print("Play with machine", machine)

    reward = float(input("Enter reward: "))

    N[selected] += 1
    R[selected] += reward
    Q[selected] = Q[selected] + (reward - Q[selected]) / N[selected]

    print("N =", N)
    print("R =", R)
    print("Q =", [round(x, 2) for x in Q])

for i in range(M):
    if N[i] == 0:
        UCB[i] = float('inf')
    else:
        UCB[i] = Q[i] + math.sqrt((2 * math.log(N_play)) / N[i])

print("\nFinal Results")
print("-----------------------------")
print("Machine\tN\tR\tUCB\tQ")
print("-----------------------------")

for i in range(M):
    ucb_value = "inf" if UCB[i] == float('inf') else round(UCB[i], 2)
    print(machines[i], "\t", N[i], "\t", R[i], "\t", ucb_value, "\t", round(Q[i], 2))

print("-----------------------------")
print("Total Reward =", sum(R))
# Out:
# Play 1
# UCB = ['inf', 'inf', 'inf']
# Play with machine A
# Enter reward: 3
# N = [1, 0, 0]
# R = [3.0, 0.0, 0.0]
# Q = [3.0, 0.0, 0.0]
#
# Play 2
# UCB = [4.18, 'inf', 'inf']
# Play with machine B
# Enter reward: 6
# N = [1, 1, 0]
# R = [3.0, 6.0, 0.0]
# Q = [3.0, 6.0, 0.0]
#
# Play 3
# UCB = [4.48, 7.48, 'inf']
# Play with machine C
# Enter reward: 4
# N = [1, 1, 1]
# R = [3.0, 6.0, 4.0]
# Q = [3.0, 6.0, 4.0]
#
# Play 4
# UCB = [4.67, 7.67, 5.67]
# Play with machine B
# Enter reward: 7
# N = [1, 2, 1]
# R = [3.0, 13.0, 4.0]
# Q = [3.0, 6.5, 4.0]
#
# Play 5
# UCB = [4.79, 7.77, 5.79]
# Play with machine B
# Enter reward: 5
# N = [1, 3, 1]
# R = [3.0, 18.0, 4.0]
# Q = [3.0, 6.0, 4.0]
#
# Play 6
# UCB = [4.89, 7.09, 5.89]
# Play with machine B
# Enter reward: 8
# N = [1, 4, 1]
# R = [3.0, 26.0, 4.0]
# Q = [3.0, 6.5, 4.0]
#
# Play 7
# UCB = [4.97, 7.49, 5.97]
# Play with machine B
# Enter reward: 8
# N = [1, 5, 1]
# R = [3.0, 34.0, 4.0]
# Q = [3.0, 6.8, 4.0]
#
# Play 8
# ...
