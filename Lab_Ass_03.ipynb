# %% [markdown]
# <a href="https://colab.research.google.com/github/AbbanapuramRamyaSri/Reinforcement-Learning/blob/main/Lab_Ass_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

machines = ['A', 'B', 'C']
M = 3
N_play = 10
epsilon = 0.2

N = [0, 0, 0]
R = [0, 0, 0]
Q = [0.0, 0.0, 0.0]

random.seed(10)

for play in range(1, N_play + 1):
    print("\nPlay", play)

    r = random.random()
    best = Q.index(max(Q))

    if r < epsilon:
        choices = [i for i in range(M) if i != best]
        selected = random.choice(choices)
        print("Exploration")
    else:
        selected = best
        print("Exploitation")

    machine = machines[selected]

    print("Play with machine", machine)
    reward = float(input("Enter reward: "))

    N[selected] += 1
    R[selected] += reward
    Q[selected] = Q[selected] + (reward - Q[selected]) / N[selected]

    print("N =", N)
    print("R =", R)
    print("Q =", [round(x, 2) for x in Q])

print("\nFinal Results")
print("-------------------------")
print("Machine\tN\tR\tQ")
print("-------------------------")

for i in range(M):
    print(machines[i], "\t", N[i], "\t", R[i], "\t", round(Q[i], 2))

print("-------------------------")
print("Total Reward =", sum(R))
# Out:
# Play 1
# Exploitation
# Play with machine A
# Enter reward: 3
# N = [1, 0, 0]
# R = [3.0, 0, 0]
# Q = [3.0, 0.0, 0.0]
#
# Play 2
# Exploitation
# Play with machine A
# Enter reward: 4
# N = [2, 0, 0]
# R = [7.0, 0, 0]
# Q = [3.5, 0.0, 0.0]
#
# Play 3
# Exploitation
# Play with machine A
# Enter reward: 4
# N = [3, 0, 0]
# R = [11.0, 0, 0]
# Q = [3.67, 0.0, 0.0]
#
# Play 4
# Exploitation
# Play with machine A
# Enter reward: 2
# N = [4, 0, 0]
# R = [13.0, 0, 0]
# Q = [3.25, 0.0, 0.0]
#
# Play 5
# Exploitation
# Play with machine A
# Enter reward: 2
# N = [5, 0, 0]
# R = [15.0, 0, 0]
# Q = [3.0, 0.0, 0.0]
#
# Play 6
# Exploitation
# Play with machine A
# Enter reward: 5
# N = [6, 0, 0]
# R = [20.0, 0, 0]
# Q = [3.33, 0.0, 0.0]
#
# Play 7
# Exploitation
# Play with machine A
# Enter reward: 3
# N = [7, 0, 0]
# R = [23.0, 0, 0]
# Q = [3.29, 0.0, 0.0]
#
# Play 8
# Exploration
# Play with machine C
# Enter reward: 6
# N = [7, 0, 1]
# R = [23.0, 0, 6.0]
# Q = [3.29, 0.0, 6.0]
#
# Play 9
# ...
