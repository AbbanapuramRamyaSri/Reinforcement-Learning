# %% [markdown]
# <a href="https://colab.research.google.com/github/AbbanapuramRamyaSri/Reinforcement-Learning/blob/main/Lab_Ass_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium

# %%
import gymnasium as gym

# Create environment
env = gym.make("CartPole-v1")

# Reset environment
state, info = env.reset()

total_reward = 0
steps = 0

while True:
    # Select random action
    action = env.action_space.sample()

    # Perform action
    next_state, reward, terminated, truncated, info = env.step(action)

    # Add reward
    total_reward += reward
    steps += 1

    # Update state
    state = next_state

    # Stop when episode ends
    if terminated or truncated:
        break

# Calculate average reward
average_reward = total_reward / steps

print("===== CartPole =====")
print("Total Reward:", total_reward)
print("Number of Steps:", steps)
print("Average Reward:", average_reward)

env.close()
# Out:
# ===== CartPole =====
# Total Reward: 36.0
# Number of Steps: 36
# Average Reward: 1.0

# %%
import gymnasium as gym

# Create environment
env = gym.make("MountainCar-v0")

# Reset environment
state, info = env.reset()

total_reward = 0
steps = 0

while True:
    # Select random action
    action = env.action_space.sample()

    # Perform action
    next_state, reward, terminated, truncated, info = env.step(action)

    # Add reward
    total_reward += reward
    steps += 1

    # Update state
    state = next_state

    # Stop when episode ends
    if terminated or truncated:
        break

# Calculate average reward
average_reward = total_reward / steps

print("===== MountainCar =====")
print("Total Reward:", total_reward)
print("Number of Steps:", steps)
print("Average Reward:", average_reward)

env.close()
# Out:
# ===== MountainCar =====
# Total Reward: -200.0
# Number of Steps: 200
# Average Reward: -1.0

# %%
import gymnasium as gym

# Create environment
env = gym.make("FrozenLake-v1")

# Reset environment
state, info = env.reset()

total_reward = 0
steps = 0

while True:
    # Select random action
    action = env.action_space.sample()

    # Perform action
    next_state, reward, terminated, truncated, info = env.step(action)

    # Add reward
    total_reward += reward
    steps += 1

    # Update state
    state = next_state

    # Stop when episode ends
    if terminated or truncated:
        break

# Calculate average reward
average_reward = total_reward / steps

print("===== FrozenLake =====")
print("Total Reward:", total_reward)
print("Number of Steps:", steps)
print("Average Reward:", average_reward)

env.close()
# Out:
# ===== FrozenLake =====
# Total Reward: 0
# Number of Steps: 8
# Average Reward: 0.0
